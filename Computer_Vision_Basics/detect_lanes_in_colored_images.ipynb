# %%
import matplotlib.image as mpimg
import matplotlib.pyplot as plt
import numpy as np
import cv2

# %%
image_color=mpimg.imread("image_lane_c.jpg")
image_gray=cv2.cvtColor(image_color, cv2.COLOR_BGR2GRAY)

# %%
image_copy=np.copy(image_color)
plt.imshow(image_copy)

# %% [markdown]
# ### Sort out white coloer from the image
#
# As the third dimension represents the RGB color spectrum we need to mask all 3. We play as well as with white color value and we lower it to 200, 210.
# `|` represents the logical `or` as we chain methods inside the dataframe

# %%
image_copy[(image_copy[:,:,0]<200) | (image_copy[:,:,1]<200) | (image_copy[:,:,2]<200)]=0

# %%
plt.imshow(image_copy)
