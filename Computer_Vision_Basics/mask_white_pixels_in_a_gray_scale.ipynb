# %% [markdown]
# ### Mask while pixels in a gray scale
#
# By doing this we will extract all the white lines and exectively we will have the road lanes. We will convert everything that is not pure white  i.e `255` to `0`.

# %%
import matplotlib.image as mpimg
import matplotlib.pyplot as plt
import numpy as np
import cv2

# %%
image_color=mpimg.imread("image_lane_c.jpg")
image_gray=cv2.cvtColor(image_color, cv2.COLOR_BGR2GRAY)
plt.imshow(image_gray,cmap="gray")
image_gray.shape
# Out:
# (540, 960)

# %%
image_copy=np.copy(image_gray)
plt.imshow(image_copy, cmap="gray")

# %%
image_copy[(image_cpoy[:,;])]
