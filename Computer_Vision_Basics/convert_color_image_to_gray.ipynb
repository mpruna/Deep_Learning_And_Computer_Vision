# %%
# %%html
# <style>
# table {float:left}
# </style>
# Out:
# <style>
# table {float:left}
# </style>

# %% [markdown]
# ### Import visualization libraries
#
# Library | Description
# -|-
# matplotlib | Matplotlib is a Python 2D plotting library which produces publication quality figures in a variety of hardcopy formats
# numpy | NumPy is a library for the Python programming language, adding support for large, multi-dimensional arrays and matrices, along with a large collection of high-level mathematical functions to operate on these arrays.
# opencv | OpenCV is a library of programming functions mainly aimed at real-time computer vision. Originally developed by Inte

# %%
import matplotlib.image as mpimg
import matplotlib.pyplot as plt
import numpy as np
import cv2

# %% [markdown]
# Module | Description
# -|-
# mping | he image module supports basic image loading, rescaling and display operations
# plt | module used for plotting
#
# After a library is loaded description and functionality can be seen with help function i.e `help(mpimg)`, `help(plt)` etc

# %% [markdown]
# ### Read image

# %%
image_color=mpimg.imread("image_lane_c.jpg")

# %% [markdown]
# ### Plot image

# %%
plt.imshow(image_color)

# %% [markdown]
# ### Dimension of the image

# %%
image_color.shape
# Out:
# (540, 960, 3)

# %% [markdown]
# shape | explanation
# -|-
# 540 | height
# 960 | lenght
# 3 | image has 3 layers coresponding to RGB

# %%
dir(image_color)
# Out:
# ['T',
#  '__abs__',
#  '__add__',
#  '__and__',
#  '__array__',
#  '__array_finalize__',
#  '__array_interface__',
#  '__array_prepare__',
#  '__array_priority__',
#  '__array_struct__',
#  '__array_ufunc__',
#  '__array_wrap__',
#  '__bool__',
#  '__class__',
#  '__complex__',
#  '__contains__',
#  '__copy__',
#  '__deepcopy__',
#  '__delattr__',
#  '__delitem__',
#  '__dir__',
#  '__divmod__',
#  '__doc__',
#  '__eq__',
#  '__float__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__iand__',
#  '__ifloordiv__',
#  '__ilshift__',
#  '__imatmul__',
#  '__imod__',
#  '__imul__',
#  '__index__',
#  '__init__',
#  '__init_subclass__',
#  '__int__',
#  '__invert__',
#  '__ior__',
#  '__ipow__',
#  '__irshift__',
#  '__isub__',
#  '__iter__',
#  '__itruediv__',
#  '__ixor__',
#  '__le__',
#  '__len__',
#  '__lshift__',
#  '__lt__',
#  '__matmul__',
#  '__mod__',
#  '__mul__',
#  '__ne__',
# ...

# %%
help(dir)
# Out:
# Help on built-in function dir in module builtins:
#
# dir(...)
#     dir([object]) -> list of strings
#
#     If called without an argument, return the names in the current scope.
#     Else, return an alphabetized list of names comprising (some of) the attributes
#     of the given object, and of attributes reachable from it.
#     If the object supplies a method named __dir__, it will be used; otherwise
#     the default dir() logic is used and returns:
#       for a module object: the module's attributes.
#       for a class object:  its attributes, and recursively the attributes
#         of its bases.
#       for any other object: its attributes, its class's attributes, and
#         recursively the attributes of its class's base classes.

# %%
image_color[0][0].shape
# Out:
# (3,)

# %%
image_color[0][0]
# Out:
# array([122, 185, 229], dtype=uint8)

# %% [markdown]
# Above shows the RGB representation of the pixel with coords(0,0) which is [122,185,229]

# %%
### Convert color image to black and white

# %%
image_gray=cv2.cvtColor(image_color, cv2.COLOR_BGR2GRAY)
plt.imshow(image_gray,cmap="gray")

# %%
image_gray.shape
# Out:
# (540, 960)

# %% [markdown]
# Confirms that image whas transformed as we don't have the color dimension

# %%
image_gray
# Out:
# array([[191, 191, 192, ..., 191, 191, 191],
#        [191, 191, 191, ..., 191, 191, 191],
#        [191, 191, 191, ..., 191, 191, 191],
#        ...,
#        [161, 163, 160, ..., 190, 191, 191],
#        [170, 168, 160, ..., 185, 186, 187],
#        [164, 156, 145, ..., 172, 173, 173]], dtype=uint8)

# %% [markdown]
# ### See complete image matrix

# %%
np.set_printoptions(threshold=np.nan)
image_gray[:1] # selection only the first element
# Out:
# array([[191, 191, 192, 191, 190, 190, 191, 192, 191, 191, 191, 191, 191,
#         191, 191, 191, 191, 191, 191, 191, 191, 191, 191, 191, 191, 191,
#         191, 191, 191, 191, 191, 191, 190, 190, 190, 190, 190, 190, 190,
#         190, 189, 189, 189, 189, 189, 189, 189, 189, 189, 189, 189, 189,
#         189, 189, 189, 189, 189, 189, 189, 189, 189, 189, 189, 189, 189,
#         189, 189, 189, 189, 189, 189, 189, 190, 190, 190, 190, 190, 190,
#         190, 190, 189, 189, 189, 189, 189, 189, 189, 188, 188, 188, 188,
#         188, 188, 188, 188, 188, 188, 188, 188, 189, 189, 189, 189, 189,
#         189, 189, 189, 189, 189, 189, 189, 189, 189, 189, 189, 189, 189,
#         189, 189, 189, 189, 189, 189, 189, 189, 189, 189, 189, 190, 190,
#         190, 190, 190, 190, 190, 190, 189, 189, 189, 189, 189, 189, 189,
#         189, 190, 190, 190, 190, 190, 190, 190, 190, 190, 190, 190, 190,
#         190, 190, 190, 190, 190, 190, 190, 190, 190, 190, 190, 190, 190,
# ...

# %%
### Save the image

# %%
cv2.imwrite("image_lane.g.jpg", image_gray)
# Out:
# True
